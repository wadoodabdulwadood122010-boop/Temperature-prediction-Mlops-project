# %%
import pandas as pd

# %%
df = pd.read_csv('../data/processed/features.csv')

# %%
df.head()
# Out:
#    city_encoded  day_of_year  month  year  temp_max_lag_1  temp_max_lag_3  \
# 0             0            7      1  2014          9.9415          9.7915
# 1             0            8      1  2014          4.8915          9.4415
# 2             0            9      1  2014          8.7915          9.9415
# 3             0           10      1  2014          8.3415          4.8915
# 4             0           11      1  2014         11.9915          8.7915
#
#    temp_max_lag_7  temp_min_lag_1  temp_min_lag_3  temp_min_lag_7  \
# 0          8.9915         -2.9585         -1.5085         -3.6585
# 1         12.6415          0.9915         -2.0585         -4.2585
# 2         14.5415         -0.5585         -2.9585         -2.8085
# 3         11.6915         -2.1085          0.9915          2.5415
# 4          9.7915         -4.0585         -0.5585         -1.5085
#
#    rolling_temp_max_7  solar_radiation  rain  temp_max
# 0           10.420071             2.51   3.6    4.8915
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(df)

# %%
x = df.drop(columns=['temp_max'])
y = df['temp_max']

# %%
from sklearn.preprocessing import t
